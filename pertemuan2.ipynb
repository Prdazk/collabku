# %% [markdown]
# <a href="https://colab.research.google.com/github/Prdazk/collabku/blob/main/pertemuan2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# pandas dataframe

pip install pandas

# %%
import pandas as pd

series = pd.Series(["selamat","pagi sayang","semangat belajarnya"])
print(series)
print(series.index)
print(series.values)
# Out:
# 0                selamat
# 1            pagi sayang
# 2    semangat belajarnya
# dtype: object
# RangeIndex(start=0, stop=3, step=1)
# ['selamat' 'pagi sayang' 'semangat belajarnya']

# %%
data= {
    'landmark':['sather Gate','conpanile','library','memorial','sun plaza'],
    'Type':['rumah','Tower','perpustakaan','lapangan terbuka','plaza'],
    'tinggi': [30,307,80,0,0],
    'Tahun dibangun': [1910,1915,1911,None,1962]
}

df_landmark = pd.DataFrame(data)
display(df_landmark)
# Out:
#       landmark              Type  tinggi  Tahun dibangun
# 0  sather Gate             rumah      30          1910.0
# 1    conpanile             Tower     307          1915.0
# 2      library      perpustakaan      80          1911.0
# 3     memorial  lapangan terbuka       0             NaN
# 4    sun plaza             plaza       0          1962.0

# %%
df_iris=pd.read_csv('/content/sample_data/iris.data',header=None)
display(df_iris)
df_iris.columns = ['panjang_kelopak','lebar_kelopak',
                   'panjang_mahkota','lebar_mahkota','label']

display(df_iris)
# Out:
#        0    1    2    3               4
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]
#      panjang_kelopak  lebar_kelopak  panjang_mahkota  lebar_mahkota  \
# 0                5.1            3.5              1.4            0.2
# 1                4.9            3.0              1.4            0.2
# 2                4.7            3.2              1.3            0.2
# 3                4.6            3.1              1.5            0.2
# 4                5.0            3.6              1.4            0.2
# ...

# %%
#@title Explore dataframe

df_iris.head(100) ##default 5
# Out:
#     panjang_kelopak  lebar_kelopak  panjang_mahkota  lebar_mahkota  \
# 0               5.1            3.5              1.4            0.2
# 1               4.9            3.0              1.4            0.2
# 2               4.7            3.2              1.3            0.2
# 3               4.6            3.1              1.5            0.2
# 4               5.0            3.6              1.4            0.2
# ..              ...            ...              ...            ...
# 95              5.7            3.0              4.2            1.2
# 96              5.7            2.9              4.2            1.3
# 97              6.2            2.9              4.3            1.3
# 98              5.1            2.5              3.0            1.1
# 99              5.7            2.8              4.1            1.3
#
#               label
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df_iris.tail()
# Out:
#      panjang_kelopak  lebar_kelopak  panjang_mahkota  lebar_mahkota  \
# 145              6.7            3.0              5.2            2.3
# 146              6.3            2.5              5.0            1.9
# 147              6.5            3.0              5.2            2.0
# 148              6.2            3.4              5.4            2.3
# 149              5.9            3.0              5.1            1.8
#
#               label
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
# ukuran dari dataframe

print(df_iris.shape)
print(df_iris.size)
# Out:
# (150, 5)
# 750

# %%
df_iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   panjang_kelopak  150 non-null    float64
#  1   lebar_kelopak    150 non-null    float64
#  2   panjang_mahkota  150 non-null    float64
#  3   lebar_mahkota    150 non-null    float64
#  4   label            150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
# explore describe
df_iris['label'].describe()
# Out:
# count             150
# unique              3
# top       Iris-setosa
# freq               50
# Name: label, dtype: object

# %%
df_iris.lebar_kelopak.describe()
# Out:
# count    150.000000
# mean       3.054000
# std        0.433594
# min        2.000000
# 25%        2.800000
# 50%        3.000000
# 75%        3.300000
# max        4.400000
# Name: lebar_kelopak, dtype: float64

# %%
df_iris.panjang_kelopak.describe()
# Out:
# count    150.000000
# mean       5.843333
# std        0.828066
# min        4.300000
# 25%        5.100000
# 50%        5.800000
# 75%        6.400000
# max        7.900000
# Name: panjang_kelopak, dtype: float64

# %%
# explore data samploe

df_landmark.sample(9,replace=True)
# Out:
#       landmark              Type  tinggi  Tahun dibangun
# 4    sun plaza             plaza       0          1962.0
# 0  sather Gate             rumah      30          1910.0
# 2      library      perpustakaan      80          1911.0
# 2      library      perpustakaan      80          1911.0
# 3     memorial  lapangan terbuka       0             NaN
# 0  sather Gate             rumah      30          1910.0
# 3     memorial  lapangan terbuka       0             NaN
# 0  sather Gate             rumah      30          1910.0
# 2      library      perpustakaan      80          1911.0

# %%
df_iris.label.unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
df_iris.label.value_counts()
# Out:
# label
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
#@title memilik dan mendapatkan data

display(df_iris.head(4))

df_iris.iloc[[1,2],[0,1]] # input parameter list [],[]
# Out:
#    panjang_kelopak  lebar_kelopak  panjang_mahkota  lebar_mahkota        label
# 0              5.1            3.5              1.4            0.2  Iris-setosa
# 1              4.9            3.0              1.4            0.2  Iris-setosa
# 2              4.7            3.2              1.3            0.2  Iris-setosa
# 3              4.6            3.1              1.5            0.2  Iris-setosa
#    panjang_kelopak  lebar_kelopak
# 1              4.9            3.0
# 2              4.7            3.2

# %%
df_iris.iloc[:,1:3]
# Out:
#      lebar_kelopak  panjang_mahkota
# 0              3.5              1.4
# 1              3.0              1.4
# 2              3.2              1.3
# 3              3.1              1.5
# 4              3.6              1.4
# ..             ...              ...
# 145            3.0              5.2
# 146            2.5              5.0
# 147            3.0              5.2
# 148            3.4              5.4
# 149            3.0              5.1
#
# [150 rows x 2 columns]

# %%
df_iris.iloc[149,2]
# Out:
# np.float64(5.1)

# %%
df_iris.loc[[149],['panjang_mahkota']] # list
df_iris.loc[:,'panjang_mahkota':'label'] # slice
df_iris.loc[149,'panjang_mahkota'] # single value
# Out:
# np.float64(5.1)

# %%
# context-dependent selection

display(df_iris[1:3]) # slice
display(df_iris[['label','panjang_kelopak']])
display(df_iris['label'])
# Out:
#    panjang_kelopak  lebar_kelopak  panjang_mahkota  lebar_mahkota        label
# 1              4.9            3.0              1.4            0.2  Iris-setosa
# 2              4.7            3.2              1.3            0.2  Iris-setosa
#               label  panjang_kelopak
# 0       Iris-setosa              5.1
# 1       Iris-setosa              4.9
# 2       Iris-setosa              4.7
# 3       Iris-setosa              4.6
# 4       Iris-setosa              5.0
# ..              ...              ...
# 145  Iris-virginica              6.7
# 146  Iris-virginica              6.3
# 147  Iris-virginica              6.5
# 148  Iris-virginica              6.2
# 149  Iris-virginica              5.9
#
# [150 rows x 2 columns]
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# ...

# %%
#@title filter dataframe

df_iris[ (df_iris['panjang_kelopak']>5) &
        (df_iris.lebar_kelopak > 4)
]

df_iris.loc[df_iris['panjang_kelopak']>5]

# simbol
# ~ negasi
# | or
# & and
# ^ xor
# Out:
#      panjang_kelopak  lebar_kelopak  panjang_mahkota  lebar_mahkota  \
# 0                5.1            3.5              1.4            0.2
# 5                5.4            3.9              1.7            0.4
# 10               5.4            3.7              1.5            0.2
# 14               5.8            4.0              1.2            0.2
# 15               5.7            4.4              1.5            0.4
# ..               ...            ...              ...            ...
# 145              6.7            3.0              5.2            2.3
# 146              6.3            2.5              5.0            1.9
# 147              6.5            3.0              5.2            2.0
# 148              6.2            3.4              5.4            2.3
# 149              5.9            3.0              5.1            1.8
#
#               label
# 0       Iris-setosa
# 5       Iris-setosa
# 10      Iris-setosa
# 14      Iris-setosa
# 15      Iris-setosa
# ..              ...
# ...

# %%
#@title modifikasi dan tambah kolom

df_iris['rata_kelopak']= (df_iris['panjang_kelopak']
                          +df_iris['lebar_kelopak'])/2
display(df_iris)
# Out:
#      panjang_kelopak  lebar_kelopak  panjang_mahkota  lebar_mahkota  \
# 0                5.1            3.5              1.4            0.2
# 1                4.9            3.0              1.4            0.2
# 2                4.7            3.2              1.3            0.2
# 3                4.6            3.1              1.5            0.2
# 4                5.0            3.6              1.4            0.2
# ..               ...            ...              ...            ...
# 145              6.7            3.0              5.2            2.3
# 146              6.3            2.5              5.0            1.9
# 147              6.5            3.0              5.2            2.0
# 148              6.2            3.4              5.4            2.3
# 149              5.9            3.0              5.1            1.8
#
#               label  rata_kelopak
# 0       Iris-setosa          4.30
# 1       Iris-setosa          3.95
# 2       Iris-setosa          3.95
# ...

# %%
df_iris.drop(columns=['rata_kelopak'],inplace=True)
display(df_iris)
# Out:
#      panjang_kelopak  lebar_kelopak  panjang_mahkota  lebar_mahkota  \
# 0                5.1            3.5              1.4            0.2
# 1                4.9            3.0              1.4            0.2
# 2                4.7            3.2              1.3            0.2
# 3                4.6            3.1              1.5            0.2
# 4                5.0            3.6              1.4            0.2
# ..               ...            ...              ...            ...
# 145              6.7            3.0              5.2            2.3
# 146              6.3            2.5              5.0            1.9
# 147              6.5            3.0              5.2            2.0
# 148              6.2            3.4              5.4            2.3
# 149              5.9            3.0              5.1            1.8
#
#               label
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df_iris.sort_values(by=['panjang_kelopak'], ascending=False)
# Out:
#      panjang_kelopak  lebar_kelopak  panjang_mahkota  lebar_mahkota  \
# 131              7.9            3.8              6.4            2.0
# 122              7.7            2.8              6.7            2.0
# 118              7.7            2.6              6.9            2.3
# 117              7.7            3.8              6.7            2.2
# 135              7.7            3.0              6.1            2.3
# ..               ...            ...              ...            ...
# 41               4.5            2.3              1.3            0.3
# 42               4.4            3.2              1.3            0.2
# 8                4.4            2.9              1.4            0.2
# 38               4.4            3.0              1.3            0.2
# 13               4.3            3.0              1.1            0.1
#
#               label
# 131  Iris-virginica
# 122  Iris-virginica
# 118  Iris-virginica
# 117  Iris-virginica
# 135  Iris-virginica
# ..              ...
# ...

# %%
df_landmark.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   landmark        5 non-null      object
#  1   Type            5 non-null      object
#  2   tinggi          5 non-null      int64
#  3   Tahun dibangun  4 non-null      float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 292.0+ bytes

# %%
df_bersih=df_landmark.dropna()
df_bersih
# Out:
#       landmark          Type  tinggi  Tahun dibangun
# 0  sather Gate         rumah      30          1910.0
# 1    conpanile         Tower     307          1915.0
# 2      library  perpustakaan      80          1911.0
# 4    sun plaza         plaza       0          1962.0

# %%
df_landmark.fillna(0)
# Out:
#       landmark              Type  tinggi  Tahun dibangun
# 0  sather Gate             rumah      30          1910.0
# 1    conpanile             Tower     307          1915.0
# 2      library      perpustakaan      80          1911.0
# 3     memorial  lapangan terbuka       0             0.0
# 4    sun plaza             plaza       0          1962.0

# %%
#@title aggregation

df_landmark.tinggi.mean()
df_landmark.tinggi.sum()
# Out:
# np.int64(417)

# %%
df_rata= df_iris.groupby('label').mean()
df_rata
# Out:
#                  panjang_kelopak  lebar_kelopak  panjang_mahkota  \
# label
# Iris-setosa                5.006          3.418            1.464
# Iris-versicolor            5.936          2.770            4.260
# Iris-virginica             6.588          2.974            5.552
#
#                  lebar_mahkota
# label
# Iris-setosa              0.244
# Iris-versicolor          1.326
# Iris-virginica           2.026

# %%
event= pd.read_csv('/content/sample_data/uc_berkeley_events.csv')
display(event)

landmark= pd.read_csv('/content/sample_data/Augmented_Landmarks_DataFrame.csv')
display(landmark)
# Out:
#    Year                                       Event      Location
# 0  1868                     Founding of UC Berkeley  Berkeley, CA
# 1  1914                     Completion of Campanile  Berkeley, CA
# 2  1923                 Opening of Memorial Stadium  Berkeley, CA
# 3  1964                        Free Speech Movement  Berkeley, CA
# 4  2000  Opening of Hearst Memorial Mining Building  Berkeley, CA
#                   Landmark        Type  Height  Year Built       Campus
# 0              Sather Gate        Gate      30      1910.0  UC Berkeley
# 1                Campanile       Tower     307      1914.0  UC Berkeley
# 2              Doe Library     Library      80      1911.0  UC Berkeley
# 3           Memorial Glade  Open Space       0         NaN  UC Berkeley
# 4             Sproul Plaza       Plaza       0      1962.0  UC Berkeley
# 5               North Gate        Gate      25      1909.0  UC Berkeley
# 6          Moffitt Library     Library      60      1970.0  UC Berkeley
# ...

# %%
hasil_join_inner = landmark.join(
    event.set_index('Year'),
    on='Year Built',
    how='inner'
    )
display(hasil_join_inner)

hasil_join_inner = landmark.merge(
    event,
    left_on='Year Built',
    right_on='Year',
    how='left'
    )
display(hasil_join_inner)
# Out:
#           Landmark   Type  Height  Year Built       Campus  \
# 1        Campanile  Tower     307      1914.0  UC Berkeley
# 10  Green Building  Tower     295      1964.0          MIT
# 18     White Plaza  Plaza       0      1964.0     Stanford
#
#                       Event      Location
# 1   Completion of Campanile  Berkeley, CA
# 10     Free Speech Movement  Berkeley, CA
# 18     Free Speech Movement  Berkeley, CA
#                   Landmark        Type  Height  Year Built       Campus  \
# 0              Sather Gate        Gate      30      1910.0  UC Berkeley
# 1                Campanile       Tower     307      1914.0  UC Berkeley
# 2              Doe Library     Library      80      1911.0  UC Berkeley
# 3           Memorial Glade  Open Space       0         NaN  UC Berkeley
# 4             Sproul Plaza       Plaza       0      1962.0  UC Berkeley
# 5               North Gate        Gate      25      1909.0  UC Berkeley
# ...

# %%
#@title visualisasi

import matplotlib.pyplot as plt

l=0.35
x =[0, 0.8, 1.6]
jml_data= df_iris.label.value_counts()
pt.bar(x,jml_data,width=1,edgecolor='black')
pt.xticks(x,jml_data.index)
pt.show()

# %%
# data quentation / variable
pt.boxplot(df_iris.panjang_kelopak,vert=False)
pt.xlabel('panjang kelopak')
pt.show()

# %%
# data quentation / variable
import matplotlib.pyplot as plt
plt.scatter(df_iris.panjang_kelopak,df_iris.lebar_kelopak)
plt.xlabel('panjang kelopak')
plt.ylabel('lebar kelopak')
plt.show()
